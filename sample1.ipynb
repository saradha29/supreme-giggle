# %% [markdown]
# <a href="https://colab.research.google.com/github/saradha29/supreme-giggle/blob/master/sample1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
image = cv2.imread("/content/dog.jfif")
print(image.shape[0])
print (image.shape[1])
print(image.shape[2])
import matplotlib.pyplot as plt
plt.imshow(image)
# Out:
# 176
# 286
# 3

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-4e91a6bc0c41> in <module>()
#       1 import cv2
#       2 pic=cv2.imread("/content/dog1.jfif")
# ----> 3 print(pic.shape[0])
#       4 print(pic.shape[1])
#       5 print (pic.shape[2])
#
# AttributeError: 'NoneType' object has no attribute 'shape'
